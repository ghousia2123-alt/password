# %%
password = input("Enter your password: ")

if len(password) < 6:
    print("Password Strength: Weak")
elif len(password) < 10:
    print("Password Strength: Medium")
else:
    print("Password Strength: Strong")
# Out:
# Enter your password: gousia
# Password Strength: Medium
